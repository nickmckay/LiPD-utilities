# %%
# Import the program and functions that we are going to be using
from lpd_library import *
library = LiPD_Library()

# %%
# Set the library directory to wherever our LiPD files are stored (locally)
library.setDir("/Users/chrisheiser1/Desktop/lipds")
# Out:
# Directory: /Users/chrisheiser1/Desktop/lipds

# %%
# Load in all LiPD files from our set directory
library.loadLipds()

# %%
# Show what LiPD files are loaded and available
library.showFiles()
# Out:
# Ant-USITASE20006.lpd
# Arc-NGTB18.Fischer.1998.lpd
# Ant-CoastalDML.Thamban.2006.lpd
# O2kLR-AlboranSea.Nieto-Moreno.2012.lpd
# SAm-QuelccayaIceThompson2013.lpd
# Arc-Forfjordalen.Loader.2013.lpd
# Asia-DLH4.lpd
# Ant-LawDomeBoreholeReconstruction.lpd
# Ant-USITASE20021.lpd
# O2kLR-CapeHatteras.Clu00e9roux.2012.lpd
# SAm-CAN9Neukom2014.lpd
# Africa-LakeTanganyi.Tierney.2010.lpd
# Arc-Kongressvatn.DAndrea.2012.lpd
# NAm-cana153.lpd
# Asia-CHP3JU.lpd
# Arc-Helama2010.lpd
# NAm-cana094.lpd
# Asia-DAOSIC.lpd
# Ocean2kHR-PacificLinsley2006Fiji1F.lpd
# Asia-KATKUW.lpd
# Africa-ColdAirCave.Sundqvist.2013.lpd
# Ocean2kHR-PacificClippertonClipp4bWu2014.lpd
# Arc-Massa2012.lpd
# SAm-LagunaEscondElbert2013.lpd
# Asia-Guliya.Thompson.1997.lpd
# Asia-GEFKJT.lpd
# Asia-KRNKAM.lpd

# %%
# Show the CSV data for one specific LiPD file
library.showCsv('Africa-LakeTanganyi.Tierney.2010.lpd')
# Out:
# {
#   "Africa-LakeTanganyi.Tierney.2010.data.PaleoData.csv": {
#     "0": [
#       "0.732792354884379",
#       "0.72179485806106",
#       "0.719682345036116",
#       "0.710299616166177",
#       "0.706522038010513",
#       "0.705265800263015",
#       "0.709255069851284",
#       "0.697909481783209",
#       "0.678324650450105",
#       "0.67909415035252",
#       "0.687096964803465",
#       "0.698054466230937",
#       "0.711134028456609",
#       "0.700394941246764",
#       "0.704487768019448",
#       "0.696492953589611",
#       "0.686306152705708",
#       "0.693608326202165",
#       "0.700320954907162",
#       "0.691433325151653",
#       "0.67169271516742",
#       "0.701446011855631",
#       "0.671915486777178",
#       "0.687820491658315",
#       "0.687699456328439",
#       "0.667955592964532",
#       "0.70234169945762",
#       "0.682723820483314",
#       "0.685328767123288",
#       "0.696865199449794",
#       "0.677796108097094",
#       "0.680478178815758",
#       "0.673900270955336",
#       "0.675624280607256",
#       "0.66978082307161",
#       "0.699555023923445",
#       "0.694014492753623",
#       "0.700264949952947",
#       "0.71549530132968",
#       "0.706830003386387",
#       "0.695170147351055",
#       "0.690758381597194",
#       "0.71558248279136",
#       "0.686857095232804",
#       "0.698091687041565",
#       "0.699900974581614",
#       "0.694334185848252",
#       "0.698898128031251",
#       "0.703555315408778",
#       "0.686484602153578",
#       "23.5781095516424",
#       "23.1248443081249",
#       "22.9533413262093",
#       "23.9183534360313",
#       "22.80168272008",
#       "23.2384162420538",
#       "23.3087504858857",
#       "23.092347140665",
#       "23.2697658290868",
#       "23.4508093312008",
#       "22.7872024241182",
#       "22.4836390364587",
#       "22.2396111621581",
#       "22.5255351904446",
#       "23.1109424211253",
#       "22.2657316418899",
#       "22.3674182883845",
#       "22.347906119736",
#       "22.5475171487827",
#       "22.5584332252964",
#       "22.2651849599365",
#       "22.8605176626506",
#       "22.9727585944882",
#       "22.1678289614522",
#       "23.1776732615803",
#       "23.1003301488633",
#       "22.8308074249195",
#       "23.360937740179",
#       "23.3570167098682",
#       "23.6993182860879",
#       "23.5985700555556",
#       "23.4489480196898"
#     ]
#   }
# }

# %%
# Show the JSON metadata for one specific LiPD file
library.showMetadata('O2kLR-AlboranSea.Nieto-Moreno.2012.lpd')
# Out:
# {
#   "pub": [
#     {
#       "pubDataUrl": "Manually Entered",
#       "year": "submitted (Oct 2014)",
#       "journal": "Nature Geoscience",
#       "title": "Robust global ocean cooling trend for the pre-industrial Common Era",
#       "author": [
#         "McGregor, H.V.",
#         "Evans, M. N.",
#         "Goosse, H.",
#         "Leduc, G.",
#         "Martrat, B.",
#         "Addison, J.A.",
#         "Mortyn, P.G.",
#         "Oppo, D.W.",
#         "Seidenkrantz, M.S.",
#         "Sicre, M.A.",
#         "Phipps, S.J.",
#         "Selvaraj, K.",
#         "Thirumalai, K.",
#         "Filipsson, H.L.",
#         "Ersek, V."
#       ],
#       "abstract": "The oceans mediate the response of global climate to natural and anthropogenic forcings. Yet for the Common Era (past 2000 years) global ocean sea surface temperature (SST) variations, and the underlying driving mechanisms, are poorly constrained. Here we present a global synthesis of Common Era SSTs derived solely from marine archives. The synthesis uses 57 individual SST reconstructions that meet strict quality control criteria. We find an SST cooling trend during 0-1800 CE that is robust against explicit tests for potential biases in the reconstructions. The surface cooling trend for 801-1800 CE is qualitatively consistent with an independent synthesis of terrestrial temperature reconstructions, and with SST simulated by an ensemble of climate model simulations using best estimates of past forcings. Single and cumulative forcing climate model simulations suggest that the ocean SST cooling trend is not a response to orbital forcing, which is globally weak over this interval, but rather to increased frequency of explosive volcanism in recent centuries. This finding provides support for the hypothesis that ocean dynamics transform episodic volcanic forcing into a centennial and global-scale cooling trend."
#     },
#     {
#       "pubDataUrl": "doi.org",
#       "year": "submitted (Oct 2014)",
#       "volume": "55",
#       "title": "Climate conditions in the westernmost Mediterranean over the last two millennia: An integrated biomarker approach",
#       "publisher": "Elsevier BV",
#       "pubYear": 2013,
#       "type": "journal-article",
#       "abstract": "The oceans mediate the response of global climate to natural and anthropogenic forcings. Yet for the Common Era (past 2000 years) global ocean sea surface temperature (SST) variations, and the underlying driving mechanisms, are poorly constrained. Here we present a global synthesis of Common Era SSTs derived solely from marine archives. The synthesis uses 57 individual SST reconstructions that meet strict quality control criteria. We find an SST cooling trend during 0-1800 CE that is robust against explicit tests for potential biases in the reconstructions. The surface cooling trend for 801-1800 CE is qualitatively consistent with an independent synthesis of terrestrial temperature reconstructions, and with SST simulated by an ensemble of climate model simulations using best estimates of past forcings. Single and cumulative forcing climate model simulations suggest that the ocean SST cooling trend is not a response to orbital forcing, which is globally weak over this interval, but rather to increased frequency of explosive volcanism in recent centuries. This finding provides support for the hypothesis that ocean dynamics transform episodic volcanic forcing into a centennial and global-scale cooling trend.",
#       "identifier": [
#         {
#           "id": "10.1016/j.orggeochem.2012.11.001",
#           "type": "doi",
#           "url": "http://dx.doi.org/10.1016/j.orggeochem.2012.11.001"
#         }
#       ],
#       "journal": "Organic Geochemistry",
#       "page": "1-10",
#       "author": [
#         "Nieto-Moreno, V.",
#         "Mart\u00ednez-Ruiz, F.",
#         "Willmott, V.",
#         "Garc\u00eda-Orellana, J.",
#         "Masqu\u00e9, P.",
#         "Sinninghe Damst\u00e9, J.S."
#       ]
#     }
#   ],
#   "studyTitle": "Age determination and paleotemperatures of sediment cores TTR17-1_384B and TTR17-1_436B in the Alboran Sea",
#   "notes": "All O2K-LR records have been quality-controlled according to protocols published in Nature Geoscience supplement",
#   "@context": "context.jsonld",
#   "paleoData": [
#     {
#       "columns": [
#         {
#           "missingValue": "NaN",
#           "parameter": "depth_cm",
#           "number": 1,
#           "dataType": "str",
#           "units": "cm",
#           "description": "depth",
#           "variableName": "depth_cm"
#         },
#         {
#           "parameter": "year",
#           "number": 2,
#           "dataType": "float",
#           "units": "AD",
#           "description": "Year AD",
#           "variableName": "year"
#         },
#         {
#           "parameter": "temp_C",
#           "climateInterpretation": {
#             "interpDirection": "positive",
#             "parameter": "T",
#             "climateParameterDetail": "sea_surface",
#             "seasonality": "Annual",
#             "parameterDetail": "sea_surface",
#             "climateParameter": "T",
#             "basis": "alkenone calibration to SST"
#           },
#           "error": "MUE1998: T(sediments) = (Uk\u201937-0.044)/0.033, (M\u00fcller et al., (1998); global (60S-60N), 0-29\u00baC, annual at 0 m, n=370, R2=0.958)",
#           "description": "inferred sea-surface temperature",
#           "variableName": "temp_C",
#           "method": "alkenone",
#           "missingValue": "NaN",
#           "archive": "marine sediments",
#           "number": 3,
#           "dataType": "float",
#           "units": "deg C",
#           "material": "alkenone"
#         },
#         {
#           "missingValue": "NaN",
#           "parameter": "native_UK_37",
#           "number": 4,
#           "dataType": "float",
#           "description": "native UK'37 ratio from which SST was calculated",
#           "variableName": "native_UK'37"
#         },
#         {
#           "missingValue": "NaN",
#           "parameter": "notes",
#           "number": 5,
#           "dataType": "str",
#           "description": "quality-controlled data from Nieto-Moreno et al. (2013) that was used in the O2K-LR analysis",
#           "variableName": "notes"
#         }
#       ],
#       "paleoDataTableName": "Data0x28QC0x29",
#       "filename": "O2kLR-AlboranSea.Nieto-Moreno.2012.Data0x28QC0x29.PaleoData.csv"
#     },
#     {
#       "columns": [
#         {
#           "missingValue": "NaN",
#           "parameter": "depth_cm",
#           "number": 1,
#           "dataType": "str",
#           "units": " cm",
#           "detail": "middle of sample",
#           "description": "depth",
#           "variableName": "depth_cm"
#         },
#         {
#           "parameter": "year",
#           "number": 2,
#           "dataType": "float",
#           "units": "AD",
#           "description": "Year AD",
#           "variableName": "year"
#         },
#         {
#           "parameter": "temp_C",
#           "climateInterpretation": {
#             "interpDirection": "positive",
#             "parameter": "T",
#             "climateParameterDetail": "sea_surface",
#             "seasonality": "Annual",
#             "parameterDetail": "sea_surface",
#             "climateParameter": "T",
#             "basis": "alkenone calibration to SST"
#           },
#           "error": "MUE1998: T(sediments) = (Uk\u201937-0.044)/0.033, (M\u00fcller et al., (1998); global (60S-60N), 0-29\u00baC, annual at 0 m, n=370, R2=0.958)",
#           "description": "inferred sea-surface temperature",
#           "variableName": "temp_C",
#           "method": "alkenone",
#           "missingValue": "NaN",
#           "archive": "marine sediments",
#           "number": 3,
#           "dataType": "float",
#           "units": "deg C",
#           "material": "alkenone"
#         },
#         {
#           "missingValue": "NaN",
#           "parameter": "native_UK_37",
#           "number": 4,
#           "dataType": "float",
#           "description": "native UK'37 ratio from which SST was calculated",
#           "variableName": "native_UK'37"
#         },
#         {
#           "missingValue": "NaN",
#           "parameter": "notes",
#           "number": 5,
#           "dataType": "str",
#           "description": "original dataset from Nieto-Moreno et al. (2013) - PLEASE USE QC DATA FOR ANALYSIS!!!!",
#           "variableName": "notes"
#         }
#       ],
#       "paleoDataTableName": "Data0x28original0x29",
#       "filename": "O2kLR-AlboranSea.Nieto-Moreno.2012.Data0x28original0x29.PaleoData.csv"
#     }
#   ],
#   "archiveType": "marine sediments",
#   "dataSetName": "O2kLR-AlboranSea.Nieto-Moreno.2012",
#   "investigators": "Nieto-Moreno, V.; Mart\u00ednez-Ruiz, F.; Willmott, V.; Garc\u00eda-Orellana, J.; Masqu\u00e9, P.; Sinninghe Damst\u00e9, J. S.",
#   "funding": [
#     {
#       "grant": "CGL2009-07603",
#       "agency": "Junta de Andaluc\u00eda"
#     },
#     {
#       "grant": "CTM2009-7715",
#       "agency": "European Research Council under the European Union\u2019s Seventh Framework Programme"
#     },
#     {
#       "grant": "200800050084447 (MARM)"
#     },
#     {
#       "grant": "Project RNM 05212"
#     },
#     {
#       "grant": "Research Group 0179 "
#     },
#     {
#       "grant": "FP7/2007-2013)/ERC Grant Agreement #226600"
#     }
#   ],
#   "geo": {
#     "properties": {
#       "siteName": "Alboran Sea",
#       "pages2kRegion": "O2kLR"
#     },
#     "type": "Feature",
#     "geometry": {
#       "coordinates": [
#         36.2053,
#         -4.3133,
#         -1108
#       ]
#     }
#   },
#   "collectionName": "Nieto-Moreno.2012.TTR17-1_436B"
# }

# %%
# "whos" function shows all variables, functions, objects, and modules currently in memory

# %%
whos
